# %% [markdown]
# #### Analisis multivariado

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set(style="darkgrid")

df = sns.load_dataset("tips")

df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df, hue="sex")
plt.show()

# %% [markdown]
# ¿Que factores afectan a que las propinas cambien en el restaurante?
# ej: tamañon de la fiesta, momento del dia, etc.

# %%
# grafico de barras de propinas promedio por sexo
sns.barplot(data=df, x="sex", y="tip", ci=None)
plt.title("propinas promedio por sexo")
plt.show()

#Hombres en propedio pagan mas propina
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_11996\1415526700.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df, x="sex", y="tip", ci=None)

# %%
sns.barplot(data=df, x="day", y="tip", errorbar=None)
plt.title("propinas promedio por dia")
plt.show()

#los domingos se pagan mas propinas

# %%
sns.barplot(data=df, x="time", y="tip", errorbar=None)
plt.title("propinas promedio por tiempo")
plt.show()

#en la cena se paga mas propina en promedio

# %%
#propinas promedio por fumador
sns.barplot(data=df, x="smoker", y="tip", errorbar=None)
plt.title("propinas promedio por fumador/no fumador")
plt.show()

#el hecho de que el cliente fume o no, no afecta  la propina

# %%
#grafico de barras de propinas promedia por el dia y sexo
sns.barplot(data=df, x="day", y="tip", hue="sex", errorbar=None)
plt.title("propinas promedio por dia y sexo")
plt.show()

# %%
#grafico de barras de propinas promedia por el tiempo y sexo
sns.barplot(data=df, x="time", y="tip", hue="sex", errorbar=None)
plt.title("propinas promedio por tiempo y sexo")
plt.show()

# %%
#grafico de barras de propinas promedia por fumador y sexo
sns.barplot(data=df, x="smoker", y="tip", hue="sex", errorbar=None)
plt.title("propinas promedio por fumador/no fumador y sexo")
plt.show()
